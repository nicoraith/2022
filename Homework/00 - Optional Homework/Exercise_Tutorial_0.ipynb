# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv (r'C:\Users\nicol\Documents\EPFL_Master\MA-3\ADA\2022\Homework\00 - Optional Homework\interactive_data.csv')
df
# Out:
#      Unnamed: 0         Intent         Gender            Age  \
# 0             1  None selected  None selected  None selected
# 1             2  None selected  None selected  None selected
# 2             3  None selected  None selected  None selected
# 3             4  None selected  None selected  None selected
# 4             5  None selected  None selected  None selected
# ..          ...            ...            ...            ...
# 535         536        Unknown           Male              5
# 536         537        Unknown           Male              5
# 537         538        Unknown           Male              5
# 538         539        Unknown           Male              5
# 539         540        Unknown           Male              5
#
#                        Race  Deaths  Population  Rate
# 0             None selected   33599   316299978  10.6
# 1                     White   22079   197369634  11.2
# 2                     Black    7765    38896382  20.0
# ...

# %% [markdown]
# # Nearly *two-thirds* of gun deaths are *suicides*

# %%
pd.unique(df['Intent'])
# Out:
# array(['None selected', 'Suicide', 'Homicide', 'Accident', 'Unknown'],
#       dtype=object)

# %%
df.groupby('Intent').count()
# Out:
#                Unnamed: 0  Gender  Age  Race  Deaths  Population  Rate
# Intent
# Accident              108     108  108   108     108         108    90
# Homicide              108     108  108   108     108         108    94
# None selected         108     108  108   108     108         108    98
# Suicide               108     108  108   108     108         108    96
# Unknown               108     108  108   108     108         108    90

# %% [markdown]
# # More than *85 percent* of suicide victims are *male*

# %%
df_suicide = df.loc[df['Intent'] == 'Suicide']
df_suicide
# Out:
#      Unnamed: 0   Intent         Gender            Age  \
# 108         109  Suicide  None selected  None selected
# 109         110  Suicide  None selected  None selected
# 110         111  Suicide  None selected  None selected
# 111         112  Suicide  None selected  None selected
# 112         113  Suicide  None selected  None selected
# ..          ...      ...            ...            ...
# 211         212  Suicide           Male              5
# 212         213  Suicide           Male              5
# 213         214  Suicide           Male              5
# 214         215  Suicide           Male              5
# 215         216  Suicide           Male              5
#
#                        Race  Deaths  Population  Rate
# 108           None selected   21058   316299978   6.7
# 109                   White   18457   197369634   9.4
# 110                   Black    1111    38896382   2.9
# 111                Hispanic    1057    54049078   2.0
# ...

# %%
df_suicide_male = df_suicide['Gender'].value_counts()
df_suicide_male
# Out:
# None selected    36
# Female           36
# Male             36
# Name: Gender, dtype: int64

# %% [markdown]
# The statement is false

# %% [markdown]
# # Around *a third* of all gun deaths are *homicides*

# %%
df_homicide = df.loc[df['Intent'] == 'Homicide']
df_homicide
# Out:
#      Unnamed: 0    Intent         Gender            Age  \
# 216         217  Homicide  None selected  None selected
# 217         218  Homicide  None selected  None selected
# 218         219  Homicide  None selected  None selected
# 219         220  Homicide  None selected  None selected
# 220         221  Homicide  None selected  None selected
# ..          ...       ...            ...            ...
# 319         320  Homicide           Male              5
# 320         321  Homicide           Male              5
# 321         322  Homicide           Male              5
# 322         323  Homicide           Male              5
# 323         324  Homicide           Male              5
#
#                        Race  Deaths  Population  Rate
# 216           None selected   11726   316299978   3.7
# 217                   White    3049   197369634   1.5
# 218                   Black    6503    38896382  16.7
# 219                Hispanic    1878    54049078   3.5
# ...

# %% [markdown]
# False statement

# %% [markdown]
# # Around *two-thirds* of homicide victims who are *males* in the *age-group of 15--34* are *black*

# %%
df_black_15_34 = df[(df['Intent'] == 'Homicide') & (df['Gender'] == 'Male') &(df['Age'] == '15 - 34')  ]
df_black_15_34
# Out:
#      Unnamed: 0    Intent Gender      Age                    Race  Deaths  \
# 300         301  Homicide   Male  15 - 34           None selected    6520
# 301         302  Homicide   Male  15 - 34                   White     913
# 302         303  Homicide   Male  15 - 34                   Black    4312
# 303         304  Homicide   Male  15 - 34                Hispanic    1166
# 304         305  Homicide   Male  15 - 34  Asian/Pacific Islander      76
# 305         306  Homicide   Male  15 - 34                   Other      54
#
#      Population  Rate
# 300    44017869  14.8
# 301    24831032   3.7
# 302     5869943  73.5
# 303     9379683  12.4
# 304     2415040   3.1
# 305     1522171   3.5

# %%
## unique function gives you the different categories that you have un the column

# %%
pd.unique(df['Age'])
# Out:
# array(['None selected', 'Under 15', '15 - 34', '35 - 64', '65+', '5'],
#       dtype=object)

# %% [markdown]
# # *Women* constitue only *15 percent* of the total *homicide* victims.

# %%
df_women = df[(df['Intent'] == 'Homicide') & (df['Gender'] == 'Female')]
df_homicide['Gender'].value_counts()
df_homicide.groupby('Gender').count()
# Out:
#                Unnamed: 0  Intent  Age  Race  Deaths  Population  Rate
# Gender
# Female                 36      36   36    36      36          36    30
# Male                   36      36   36    36      36          36    32
# None selected          36      36   36    36      36          36    32

# %% [markdown]
# False statement
